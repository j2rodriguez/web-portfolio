# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformaciones para las imágenes
transformaciones = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  # imágenes en escala de grises
])

# Ruta al dataset
ruta_dataset = r"C:\Users\j2rod\Documents\MASTER IA\Modulo 4\Ejercicio 4.1\X-ray Imaging Dataset for Detecting Fractured vs. Non-Fractured Bones\Original Dataset"

# Cargar dataset desde las carpetas
dataset = datasets.ImageFolder(root=ruta_dataset, transform=transformaciones)

# División en entrenamiento y prueba
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# Cargadores de datos
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Verifica las clases
print("Clases:", dataset.classes)
print("Cantidad total de imágenes:", len(dataset))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      19 train_size = int(0.8 * len(dataset))
#      20 test_size = len(dataset) - train_size
# ---> 21 train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
#      23 # Cargadores de datos
#      24 train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
#
# NameError: name 'random_split' is not defined
